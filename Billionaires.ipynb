# %% [markdown]
# # Assessment - Written By Arjun A.M

# %%
#Library importing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset
fb=pd.read_csv('Gr_1_forbes_2022_billionaires.csv')

# %% [markdown]
# # Basic Analysis

# %% [markdown]
# Head

# %%
fb.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %% [markdown]
# Tail

# %%
fb.tail()
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2663  2578            Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578               Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#            category                   source country state  ... organization  \
# 2663  Manufacturing               Fiberglass   China   NaN  ...          NaN
# 2664     Technology               Navigation   China   NaN  ...          NaN
# 2665  Manufacturing                chemicals   China   NaN  ...          NaN
# 2666         Energy  liquefied petroleum gas   China   NaN  ...          NaN
# 2667  Manufacturing                polyester   China   NaN  ...          NaN
#
#      selfMade gender   birthDate title philanthropyScore residenceMsa  \
# ...

# %% [markdown]
# Size

# %%
fb.size
# Out:
# 58696

# %% [markdown]
# Shape

# %%
fb.shape
# Out:
# (2668, 22)

# %% [markdown]
# Info

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2582 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   source                2668 non-null   object
#  8   country               2655 non-null   object
#  9   state                 748 non-null    object
#  10  city                  2624 non-null   object
#  11  countryOfCitizenship  2668 non-null   object
#  12  organization          352 non-null    object
#  13  selfMade              2668 non-null   bool
#  14  gender                2652 non-null   object
# ...

# %% [markdown]
# Columns

# %%
fb.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %% [markdown]
# Data Types

# %%
fb.dtypes
# Out:
# rank                      int64
# personName               object
# age                     float64
# finalWorth              float64
# year                      int64
# month                     int64
# category                 object
# source                   object
# country                  object
# state                    object
# city                     object
# countryOfCitizenship     object
# organization             object
# selfMade                   bool
# gender                   object
# birthDate                object
# title                    object
# philanthropyScore       float64
# residenceMsa             object
# numberOfSiblings        float64
# bio                      object
# about                    object
# dtype: object

# %% [markdown]
# Checking for missing values

# %%
fb.isnull().sum()
# Out:
# rank                       0
# personName                 0
# age                       86
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# country                   13
# state                   1920
# city                      44
# countryOfCitizenship       0
# organization            2316
# selfMade                   0
# gender                    16
# birthDate                 99
# title                   2267
# philanthropyScore       2272
# residenceMsa            2029
# numberOfSiblings        2541
# bio                        0
# about                   1106
# dtype: int64

# %% [markdown]
# # Insights

# %% [markdown]
# ## 1. Top 10 Billionaires

# %%
top_10_billionaires = fb.nsmallest(10, 'rank')
top_10_billionaires[['personName', 'rank', 'finalWorth']]
# Out:
#                  personName  rank  finalWorth
# 0                 Elon Musk     1    219000.0
# 1                Jeff Bezos     2    171000.0
# 2  Bernard Arnault & family     3    158000.0
# 3                Bill Gates     4    129000.0
# 4            Warren Buffett     5    118000.0
# 5                Larry Page     6    111000.0
# 6               Sergey Brin     7    107000.0
# 7             Larry Ellison     8    106000.0
# 8             Steve Ballmer     9     91400.0
# 9             Mukesh Ambani    10     90700.0

# %% [markdown]
# ## 2. Male and Female (Pie)

# %%
gender_counts = fb['gender'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title("Gender Distribution - Billionaires")
# Out:
# Text(0.5, 1.0, 'Gender Distribution - Billionaires')

# %% [markdown]
# # 3. People who are from India

# %%
indian_billionaires = fb[fb['countryOfCitizenship'] == 'India']
indian_billionaires[['personName', 'rank', 'finalWorth']]
# Out:
#                  personName  rank  finalWorth
# 9             Mukesh Ambani    10     90700.0
# 10    Gautam Adani & family    11     90000.0
# 46               Shiv Nadar    47     28700.0
# 56         Cyrus Poonawalla    56     24300.0
# 80       Radhakishan Damani    81     20000.0
# ...                     ...   ...         ...
# 2626            G.V. Prasad  2578      1000.0
# 2628  Jupally Rameshwar Rao  2578      1000.0
# 2639          Dhruv Sawhney  2578      1000.0
# 2642  Ramesh Chandra Sharma  2578      1000.0
# 2648     Bhawari Bai Surana  2578      1000.0
#
# [166 rows x 3 columns]

# %% [markdown]
# # 4.Tech Billionaires

# %%
tech_billionaires = fb[fb['category'] == 'Technology']
tech_billionaires[['personName', 'rank', 'finalWorth']]
# Out:
#                    personName  rank  finalWorth
# 1                  Jeff Bezos     2    171000.0
# 3                  Bill Gates     4    129000.0
# 5                  Larry Page     6    111000.0
# 6                 Sergey Brin     7    107000.0
# 7               Larry Ellison     8    106000.0
# ...                       ...   ...         ...
# 2653  Shigefumi Wada & family  2578      1000.0
# 2656          Shintaro Yamada  2578      1000.0
# 2657        Mark Haoyong Yang  2578      1000.0
# 2660              Ye Qiongjiu  2578      1000.0
# 2664               Zhou Ruxin  2578      1000.0
#
# [343 rows x 3 columns]

# %% [markdown]
# # 5. Pie chart of the billionaires who are self made

# %%
self_made_counts = fb['selfMade'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(self_made_counts, labels=['Self-Made', 'Not Self-Made'], autopct='%1.1f%%', startangle=140, colors=['#66c2a5', '#fc8d62'])
plt.title('Distribution of Billionaires: Self-Made vs. Not Self-Made')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
plt.show()
